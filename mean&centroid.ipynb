# %%
#mean & centroid
'''
centroid is compaire with mean value 
for example - 
   it compare the age value with their capability of spending money

'''
#mean
list =[100,150,200, 210,300]

mean= sum(list) / len(list)
print('Mean :' , mean)

#centroid

'''
#distance(Eucliden)
 distance =sqrt(x2 -x1)^2 +(y2-y1)^2
 x1, y1 = age, spending
 x2, y2 = customerb ar age & spending
'''

import matplotlib.pyplot as plt
import numpy as np

x= [20, 30]
y=[100,200]

plt.figure(figsize=(10,6))
plt.plot(x, y, color= 'blue')
plt.xlabel("Age")
plt.ylabel("amount of spend money")
plt.show()

distance = np.sqrt(((x[1]-x[0])*(x[1]-x[0]))+((y[1]-y[0])*(y[1]-y[0])))
print(round(distance, 2))

x.append(25)
y.append(150)
distance2 = np.sqrt(((x[2]-x[1])*(x[2]-x[1]))+((y[2]-y[1])*(y[2]-y[1])))
print(round(distance2, 2))
# Out:
# Mean : 192.0
# 100.5
# 50.25
