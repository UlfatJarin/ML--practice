# %%
# project1 

import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

data = pd.read_csv("student.csv")

X= data[['Hours']] 
y= data['Score'] #target column

model = LinearRegression()
model.fit(X,y)

predicted_score = model.predict(X)

mae = mean_absolute_error(y, predicted_score)
mse = mean_squared_error(y, predicted_score)
rmse = np.sqrt(mse)

print("MAE : ", mae)
print("MSE : ", mse)
print("RMSE : ",rmse)

new_hour = float(input("enter a Hour= "))
new_pred = model.predict([[new_hour]])
print(f"Prediction for {new_hour} is score ={new_pred}")
# Out:
# MAE :  0.6666666666666643
# MSE :  0.6285714285714282
# RMSE :  0.7928249671720916
# Prediction for 4.0 is score =[69.34285714]
# c:\Users\Dell XPS\Desktop\ML\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#2nd project 
'''
3step formula

1st = X and y are numeric? = yes
    - scatter plot 
      relationship

2nd = Is one column a catagory ?
    - Bar plot /count Plot

3rd = want to see a distribution shape ?
    - histogram / KDE Plot / Box plot
    
'''
'''
in project 

1st - find problem 

problem- 
 1 . if hour of studies will efect in ther final exam ?
    - compare with there weakly study hour
   




'''
